# %% [markdown]
# # Relatório de Análise VII

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')
dados.head(50)
# Out:
#                   Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0            Quitinete                Copacabana        1      0       0
# 1                 Casa           Jardim Botânico        2      0       1
# 2          Apartamento                    Centro        1      0       0
# 3          Apartamento              Higienópolis        1      0       0
# 4          Apartamento              Vista Alegre        3      1       0
# 5          Apartamento                  Cachambi        2      0       0
# 6   Casa de Condomínio           Barra da Tijuca        5      4       5
# 7   Casa de Condomínio                     Ramos        2      2       0
# 8          Apartamento                    Centro        1      0       0
# 9          Apartamento                    Grajaú        2      1       0
# 10         Apartamento       Lins de Vasconcelos        3      1       1
# 11         Apartamento                Copacabana        1      0       1
# ...

# %%
# Valor medio do aluguel geral
dados['Valor'].mean()
# Out:
# 4985.730140445705

# %%
# A atividade consiste em saber o preço médio de cada bairro

# %%
# Obtendo os bairros sem duplicidades
dados['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4           Vista Alegre
#               ...
# 14500         Cavalcanti
# 15806       Rio da Prata
# 15940      Cidade Jardim
# 16994        Coelho Neto
# 18257            Grumari
# Name: Bairro, Length: 154, dtype: object

# %%
# Variável que recebe o data frame 'dados' agrupado por bairros
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# A váriabel está guardando um objeto do tipo DataFrameGoupBy
grupo_bairro

# %%
''' Ao fazer um goupby na base de dados, a variável grupo_bairro recebeu um data frame para cada bairro diferente
    sendo possível trabalhar com todos os elementos que estejam na tabela desde que seja relacionado com o bairro'''
# Out:
# ' Ao fazer um goupby na base de dados, a variável grupo_bairro recebeu um data frame para cada bairro diferente\n    sendo possível trabalhar com todos os elementos que estejam na tabela desde que seja relacionado com o bairro'

# %%
# Indica o nome do bairro e qual indice onde esse bairro foi encontrado no data frame
grupo_bairro.groups
# Out:
# {'Abolição': Int64Index([ 1596,  3283,  6883,  7190,  7899, 10167, 10500, 13617, 14679,
#              16608, 17210, 17733, 19450, 19458, 20802, 22130],
#             dtype='int64'),
#  'Alto da Boa Vista': Int64Index([2270, 12452, 12988, 13699, 13905, 15018], dtype='int64'),
#  'Anchieta': Int64Index([3112, 8511, 9188, 13062, 16012, 16198, 18434], dtype='int64'),
#  'Andaraí': Int64Index([  395,   464,   529,   631,   813,   870,   878,  1026,  1225,
#               1455,  1460,  1735,  1968,  2076,  2205,  2764,  3234,  3315,
#               3598,  3691,  3860,  3982,  4365,  4721,  4927,  5035,  5042,
#               5122,  5731,  5947,  6193,  6444,  6669,  6753,  7150,  7417,
#               7667,  8162,  8163,  8342,  8723,  9506,  9611,  9655,  9706,
#              10059, 10279, 10463, 10622, 10643, 11241, 11324, 11331, 11467,
#              11918, 12227, 12714, 13202, 13703, 13850, 13854, 14247, 14377,
# ...

# %%
# print de todos os bairros diferentes
for bairro, data in grupo_bairro:
    print(bairro)
# Out:
# Abolição
# Alto da Boa Vista
# Anchieta
# Andaraí
# Anil
# Arpoador
# Bancários
# Bangu
# Barra da Tijuca
# Barra de Guaratiba
# Benfica
# Bento Ribeiro
# Bonsucesso
# Botafogo
# Braz de Pina
# Cachambi
# Cachamorra
# Cacuia
# Caju
# Camorim
# Campinho
# Campo Grande
# Cascadura
# Catete
# Catumbi
# Cavalcanti
# Centro
# Cidade Jardim
# Cidade Nova
# Cocotá
# Coelho Neto
# Colégio
# Copacabana
# Cordovil
# Cosme Velho
# Cosmos
# Curicica
# Del Castilho
# Encantado
# Engenho Novo
# Engenho da Rainha
# Engenho de Dentro
# Estácio
# Flamengo
# Freguesia (Ilha do Governador)
# Freguesia (Jacarepaguá)
# Fátima
# Gamboa
# Gardênia Azul
# Glória
# Grajaú
# Grumari
# Guadalupe
# Guaratiba
# Gávea
# Higienópolis
# Honório Gurgel
# Humaitá
# Icaraí
# Ilha do Governador
# Inhaúma
# Inhoaíba
# Ipanema
# Irajá
# Itanhangá
# Jabour
# Jacarepaguá
# Jacaré
# Jardim América
# Jardim Botânico
# Jardim Carioca
# Jardim Guanabara
# Jardim Oceânico
# Jardim Sulacap
# Joá
# Lagoa
# Lapa
# Laranjeiras
# ...

# %%
# Print de todas as tabelas agrupadas por bairro
for bairro, data in grupo_bairro:
    print(dados)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# ...

# %%
# A variável grupo bairro
for bairro, dados in grupo_bairro:
    print(type(dados))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
for bairro, data in grupo_bairro:
    print(f'{bairro} --> {data.Valor.mean()}')
# Out:
# Abolição --> 1195.625
# Alto da Boa Vista --> 3966.6666666666665
# Anchieta --> 784.2857142857143
# Andaraí --> 1463.030612244898
# Anil --> 1987.3684210526317
# Arpoador --> 12429.76923076923
# Bancários --> 1825.0
# Bangu --> 998.75
# Barra da Tijuca --> 7073.721754654425
# Barra de Guaratiba --> 5550.0
# Benfica --> 904.2857142857143
# Bento Ribeiro --> 1012.9166666666666
# Bonsucesso --> 1218.0882352941176
# Botafogo --> 8690.962879640045
# Braz de Pina --> 1082.6923076923076
# Cachambi --> 1169.3211678832117
# Cachamorra --> 3000.0
# Cacuia --> 916.6666666666666
# Caju --> 850.0
# Camorim --> 1735.2272727272727
# Campinho --> 1010.0
# Campo Grande --> 1196.7617260787993
# Cascadura --> 1054.2105263157894
# Catete --> 2271.1728395061727
# Catumbi --> 1177.7777777777778
# Cavalcanti --> 663.3333333333334
# Centro --> 1355.4022988505747
# Cidade Jardim --> 12000.0
# Cidade Nova --> 1400.0
# Cocotá --> 1883.3333333333333
# Coelho Neto --> 700.0
# Colégio --> 903.3333333333334
# ...

# %%
valor_medio = pd.DataFrame(grupo_bairro[['Valor', 'Condominio']].mean().round(2))

# %%
valor_medio
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.62      287.10
# Alto da Boa Vista  3966.67      885.00
# Anchieta            784.29       79.00
# Andaraí            1463.03      513.60
# Anil               1987.37      505.70
# ...                    ...         ...
# Vila Valqueire     1741.80      369.17
# Vila da Penha      1220.16      322.65
# Vista Alegre       1087.14      224.07
# Zumbi              2150.00     1050.00
# Água Santa          860.00      303.12
#
# [154 rows x 2 columns]

# %%
# Rodar novamente a base de dados para não dar erro nessa seleção
# Apenas conferindo se a média está certa
dados.loc[[9767,12192]]
# Out:
#               Tipo Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 9767   Apartamento  Zumbi        2      1       0    64  1600.0       500.0
# 12192  Apartamento  Zumbi        3      0       0    90  2700.0      1600.0
#
#         IPTU  Valor m2 Tipo Agregado
# 9767    60.0      25.0   Apartamento
# 12192  172.0      30.0   Apartamento

# %% [markdown]
# # Estatistica Descritiva

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            16.0  1195.62   410.90   800.0   900.0  1190.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             7.0   784.29   150.21   600.0   695.0   700.0   900.0
# Andaraí             98.0  1463.03   406.34   700.0  1200.0  1400.0  1650.0
# Anil                76.0  1987.37  1491.59   300.0  1052.5  1345.0  2600.0
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      50.0  1741.80  2162.44   800.0  1000.0  1250.0  1675.0
# Vila da Penha      124.0  1220.16   611.88   450.0   900.0  1100.0  1300.0
# Vista Alegre        21.0  1087.14   196.52   700.0   900.0  1100.0  1200.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa          10.0   860.00   164.65   600.0   800.0   850.0   925.0
#
#                        max
# Bairro
# ...

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Mínima', 'max': 'Máxima', 'sum': 'Soma'})
# Out:
#                    mínima   Máxima      Soma
# Bairro
# Abolição            800.0   2300.0   19130.0
# Alto da Boa Vista   600.0  15000.0   23800.0
# Anchieta            600.0   1000.0    5490.0
# Andaraí             700.0   2950.0  143377.0
# Anil                300.0   7000.0  151040.0
# ...                   ...      ...       ...
# Vila Valqueire      800.0  16000.0   87090.0
# Vila da Penha       450.0   4500.0  151300.0
# Vista Alegre        700.0   1400.0   22830.0
# Zumbi              1600.0   2700.0    4300.0
# Água Santa          600.0   1200.0    8600.0
#
# [154 rows x 3 columns]

# %%
# O comando destacado com '%' diz para que o grafico seja plotado no output do jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize =(50,20))

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color ='Blue')
fig.set_ylabel('Vaor do Aluguel')
fig.set_title('Valor médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor médio do Aluguel por Bairro')
